# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_absolute_percentage_error
from sklearn.datasets import load_iris

# %%
# df = pd.read_excel("Appened Years Dataset.xlsx")
df = pd.read_excel("Appended 3.xlsx")

# %%
# for i, val in enumerate(df["Year"].iloc):
#     if df["Year"].iloc[i] != df["Year"].iloc[i-1]+1:
#         df.drop(df["Year"].iloc[i])

# df.to_excel("Appended 2.xlsx")

# %%
# rows = df[df["Year"] == df["Previous Year"] + 1]
# rows.to_excel("Appended 2.xlsx")
# rows

# %%
# df1 = df.drop(["Unnamed: 0.1", "Unnamed: 0"], axis=1)
# df1 = pd.get_dummies(df1, columns=["Type"], dtype=int)
# df1 = pd.get_dummies(df1, columns=["subtype"],dtype=int)

# df1 = df1[df1.iloc[:,0] == df1.iloc[:,6]].reset_index(drop=True)

# df1.to_excel("Appended 3.xlsx")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ein', 'Year', 'Accounts', 'Contributions', 'Grants',
#        'Assets', 'ein_2', 'Previous Year', 'Accounts_2', 'Contributions_2',
#        'Grants_2', 'Assets_2', 'Type_Community Foundation', 'Type_National',
#        'Type_Single Issue', 'Type_Single Issue Charity', 'subtype_Community',
#        'subtype_Donation Processor', 'subtype_Other',
#        'subtype_Religiously-Affiliated', 'subtype_Standard',
#        'subtype_Universities and Healthcare'],
#       dtype='object')

# %%
x = df[['Previous Year', 'Accounts_2', 'Contributions_2', 'Grants', 'Assets', 'Type_Community Foundation', 'Type_National',
       'Type_Single Issue', 'Type_Single Issue Charity', 'subtype_Community',
       'subtype_Donation Processor', 'subtype_Other',
       'subtype_Religiously-Affiliated', 'subtype_Standard',
       'subtype_Universities and Healthcare']]
y = df["Contributions"]

scaler = StandardScaler()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 40)

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.fit_transform(x_test)

# %%
model = LinearRegression()
model.fit(x_train_scaled, y_train)

predictions = model.predict(x_test_scaled)

def relative_error(actual_col, predicted_col):
    valid_rows = df[df[predicted_col].notna()&df[actual_col].notna()&(df[actual_col] !=0)]
    total_actual = valid_rows[actual_col]
    total_predicted = valid_rows[predicted_col]
    RE = abs((total_actual - total_predicted)).sum() / len(total_actual)
    ME =(abs((total_actual - total_predicted)/total_actual)).median()
    return ME

print(relative_error(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 14
#      11     ME =(abs((total_actual - total_predicted)/total_actual)).median()
#      12     return ME
# ---> 14 print(relative_error(y_test, predictions))
#
# Cell In[11], line 7, in relative_error(actual_col, predicted_col)
#       6 def relative_error(actual_col, predicted_col):
# ----> 7     valid_rows = df[df[predicted_col].notna()&df[actual_col].notna()&(df[actual_col] !=0)]
#       8     total_actual = valid_rows[actual_col]
#       9     total_predicted = valid_rows[predicted_col]
#
# File c:\Users\marsh\Downloads\New folder\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\marsh\Downloads\New folder\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\marsh\Downloads\New folder\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([ 4175078.5659910813,   235296264.6211363,   5881134.132290281,\n         1880544.598912008,    4144249.36031498,   4631382.712582812,\n        4144138.1010567173,  2701017.7432621643,  11652410.689650811,\n         7733445.162003964,\n       ...\n         5074427.480720989,  381494.41982541233,   4591359.488035448,\n         5463545.498970874, -251605.58534573764,  2025380.8590562046,\n         761029.1919011399,   6623175.503177635,  4013599.5076794475,\n        3354714.1595141143],\n      dtype='float64', length=2017)] are in the [columns]"
