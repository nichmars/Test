# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, mean_absolute_error
from sklearn.datasets import load_iris

# %%
df = pd.read_excel("Appened Years Dataset.xlsx")

# %%
# for i, val in enumerate(df["Year"].iloc):
#     if df["Year"].iloc[i] != df["Year"].iloc[i-1]+1:
#         df.drop(df["Year"].iloc[i])

# df.to_excel("Appended 2.xlsx")

# %%
rows = df[df["Year"] == df["Previous Year"] + 1]
rows.to_excel("Appended 2.xlsx")
rows
# Out:
#       Unnamed: 0        ein  Year  Accounts  Contributions   Grants  \
# 1              1   10391479  2008       276      8389212.0  7419626
# 2              2   10391479  2009       278     10016375.0  8857052
# 3              3   10391479  2010       284     14088617.0  7569699
# 4              4   10391479  2011       296     19783555.0  9802671
# 5              5   10391479  2012       307     11504387.0  9544622
# ...          ...        ...   ...       ...            ...      ...
# 9003        9003  591099774  2017         0            0.0        0
# 9006        9006  631154984  2008         0            0.0        0
# 9008        9008  650024030  2009         0            0.0        0
# 9010        9010  721508036  2008         0            0.0        0
# 9012        9012  742408532  2024         1            0.0        0
#
#            Assets                  Type    subtype        ein_2  \
# 1      68897739.0  Community Foundation  Community   10391479.0
# 2      83057576.0  Community Foundation  Community   10391479.0
# 3      97807493.0  Community Foundation  Community   10391479.0
# 4     106056922.0  Community Foundation  Community   10391479.0
# 5     119272982.0  Community Foundation  Community   10391479.0
# ...           ...                   ...        ...          ...
# 9003          0.0          Single Issue      Other  591099774.0
# 9006          0.0  Community Foundation  Community  631154984.0
# 9008          0.0  Community Foundation  Community  650024030.0
# 9010          0.0  Community Foundation  Community  721508036.0
# 9012      50000.0  Single Issue Charity      Other  742408532.0
#
#       Previous Year  Accounts_2  Contributions_2    Grants_2     Assets_2
# 1            2007.0       270.0       13347384.0  10628512.0   95282896.0
# 2            2008.0       276.0        8389212.0   7419626.0   68897739.0
# 3            2009.0       278.0       10016375.0   8857052.0   83057576.0
# 4            2010.0       284.0       14088617.0   7569699.0   97807493.0
# 5            2011.0       296.0       19783555.0   9802671.0  106056922.0
# ...             ...         ...              ...         ...          ...
# 9003         2016.0         0.0              0.0         0.0          0.0
# 9006         2007.0         0.0              0.0         0.0          0.0
# 9008         2008.0         0.0              0.0         0.0          0.0
# 9010         2007.0         0.0              0.0         0.0          0.0
# 9012         2023.0         1.0              0.0         0.0      50000.0
#
# [8070 rows x 15 columns]

# %%
# x = df[["Year", ]]
