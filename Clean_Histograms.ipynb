# %%
df_error_accounts = df[~np.isinf(df['Actual Error Accounts'])]
cleaned_errors_accounts = [x for x in df_error_accounts['Actual Error Accounts'] if not np.isnan(x) and x < 10 ]

#print(cleaned_errors_accounts)

plt.hist(cleaned_errors_accounts, bins = 110)

plt.title("Hist of Acounts Error")
plt.ylabel("Frequency")
plt.xlabel("Error")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-611/2961598353.py in <cell line: 0>()
# ----> 1 df_error_accounts = df[~np.isinf(df['Actual Error Accounts'])]
#       2 cleaned_errors_accounts = [x for x in df_error_accounts['Actual Error Accounts'] if not np.isnan(x) and x < 10 ]
#       3
#       4 #print(cleaned_errors_accounts)
#       5
#
# NameError: name 'df' is not defined

# %%
df_error_contributions = df[~np.isinf(df['Actual Error Contributions'])]
cleaned_errors_contributions = [x for x in df_error_contributions['Actual Error Contributions'] if not np.isnan(x) and x < 10 ]

#print(cleaned_errors_contributions)

plt.hist(cleaned_errors_contributions, bins = 110)

plt.title("Hist of Contributions Error")
plt.ylabel("Frequency")
plt.xlabel("Error")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-611/1931405260.py in <cell line: 0>()
# ----> 1 df_error_contributions = df[~np.isinf(df['Actual Error Contributions'])]
#       2 cleaned_errors_contributions = [x for x in df_error_contributions['Actual Error Contributions'] if not np.isnan(x) and x < 10 ]
#       3
#       4 #print(cleaned_errors_contributions)
#       5
#
# NameError: name 'df' is not defined

# %%
df_error_grants = df[~np.isinf(df['Actual Error Grants'])]
cleaned_errors_grants = [x for x in df_error_grants['Actual Error Grants'] if not np.isnan(x) and x < 10 ]

#print(cleaned_errors_grants)

plt.hist(cleaned_errors_grants, bins = 110)

plt.title("Hist of Grants Error")
plt.ylabel("Frequency")
plt.xlabel("Error")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-611/558357631.py in <cell line: 0>()
# ----> 1 df_error_grants = df[~np.isinf(df['Actual Error Grants'])]
#       2 cleaned_errors_grants = [x for x in df_error_grants['Actual Error Grants'] if not np.isnan(x) and x < 10 ]
#       3
#       4 #print(cleaned_errors_grants)
#       5
#
# NameError: name 'df' is not defined

# %%
df_error_assets = df[~np.isinf(df['Actual Error Assets'])]
cleaned_errors_assets = [x for x in df_error_assets['Actual Error Assets'] if not np.isnan(x) and x < 10 ]

#print(cleaned_errors_assets)

plt.hist(cleaned_errors_assets, bins = 110)

plt.title("Hist of Assets Error")
plt.ylabel("Frequency")
plt.xlabel("Error")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-611/2560101437.py in <cell line: 0>()
# ----> 1 df_error_assets = df[~np.isinf(df['Actual Error Assets'])]
#       2 cleaned_errors_assets = [x for x in df_error_assets['Actual Error Assets'] if not np.isnan(x) and x < 10 ]
#       3
#       4 #print(cleaned_errors_assets)
#       5
#
# NameError: name 'df' is not defined
