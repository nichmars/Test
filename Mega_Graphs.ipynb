# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.linear_model import LinearRegression
# from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
# drive.mount('/content/drive')

# %%
file = 'Work onCleaning and Combining the Datasets\Filtered Data with Subtypes.xlsx'
df = pd.read_excel(file)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\marsh\AppData\Local\Temp\ipykernel_15136\1796226702.py:1: SyntaxWarning: invalid escape sequence '\F'
#   file = 'Work onCleaning and Combining the Datasets\Filtered Data with Subtypes.xlsx'

# %%
num_col_list = ["Accounts", "Contributions", "Grants", "Assets"]
num_df = df[num_col_list]
df
# Out:
#              ein  Year  Accounts  Contributions      Grants       Assets  \
# 0       10391479  2007       270     13347384.0  10628512.0   95282896.0
# 1       10391479  2008       276      8389212.0   7419626.0   68897739.0
# 2       10391479  2009       278     10016375.0   8857052.0   83057576.0
# 3       10391479  2010       284     14088617.0   7569699.0   97807493.0
# 4       10391479  2011       296     19783555.0   9802671.0  106056922.0
# ...          ...   ...       ...            ...         ...          ...
# 10418  943168507  2019         0       193000.0         0.0          0.0
# 10419  943396165  2018         0            0.0         0.0          0.0
# 10420  951744348  2007         0            0.0         0.0          0.0
# 10421  954132414  2010         0            0.0         0.0          0.0
# 10422  956105984  2020         7            0.0     14000.0          0.0
#
#                        Type                      subtype
# 0      Community Foundation                    Community
# 1      Community Foundation                    Community
# 2      Community Foundation                    Community
# 3      Community Foundation                    Community
# 4      Community Foundation                    Community
# ...                     ...                          ...
# 10418          Single Issue                          NaN
# 10419          Single Issue                          NaN
# 10420          Single Issue                          NaN
# 10421          Single Issue                          NaN
# 10422  Single Issue Charity  Universities and Healthcare
#
# [10423 rows x 8 columns]

# %%
sns.pairplot(num_df);

# %%
df2 = df.drop(["ein"], axis = 1)
sns.pairplot(df2);
