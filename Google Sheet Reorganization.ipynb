# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
j_df = pd.read_excel('Annual+DAF+Report+2025+Dataset.xlsx')

# %%
j_df_conf = j_df.copy()

j_df_conf.loc[j_df_conf['source_record'] == "IRS 990", 'source_record'] = "Confirmed"
j_df_conf.loc[j_df_conf['source_record'] == "NPT Historical Data", 'source_record'] = "Confirmed"
j_df_conf.loc[j_df_conf['source_record'] == "Paper Submission", 'source_record'] = "Confirmed"

j_df_conf.loc[j_df_conf['source_number_of_accounts'] == "IRS 990", 'source_number_of_accounts'] = "Confirmed"
j_df_conf.loc[j_df_conf['source_number_of_accounts'] == "NPT Historical Data", 'source_number_of_accounts'] = "Confirmed"
j_df_conf.loc[j_df_conf['source_number_of_accounts'] == "Paper Submission", 'source_number_of_accounts'] = "Confirmed"

j_df_conf.loc[j_df_conf['source_total_daf_contributions'] == "IRS 990", 'source_total_daf_contributions'] = "Confirmed"
j_df_conf.loc[j_df_conf['source_total_daf_contributions'] == "NPT Historical Data", 'source_total_daf_contributions'] = "Confirmed"
j_df_conf.loc[j_df_conf['source_total_daf_contributions'] == "Paper Submission", 'source_total_daf_contributions'] = "Confirmed"

j_df_conf.loc[j_df_conf['source_total_daf_grants'] == "IRS 990", 'source_total_daf_grants'] = "Confirmed"
j_df_conf.loc[j_df_conf['source_total_daf_grants'] == "NPT Historical Data", 'source_total_daf_grants'] = "Confirmed"
j_df_conf.loc[j_df_conf['source_total_daf_grants'] == "Paper Submission", 'source_total_daf_grants'] = "Confirmed"

j_df_conf.loc[j_df_conf['source_eoy_daf_assets'] == "IRS 990", 'source_eoy_daf_assets'] = "Confirmed"
j_df_conf.loc[j_df_conf['source_eoy_daf_assets'] == "NPT Historical Data", 'source_eoy_daf_assets'] = "Confirmed"
j_df_conf.loc[j_df_conf['source_eoy_daf_assets'] == "Paper Submission", 'source_eoy_daf_assets'] = "Confirmed"


j_df_conf = j_df_conf[(j_df_conf['source_record'] == 'Confirmed') & (j_df_conf['source_number_of_accounts'] == 'Confirmed') & (j_df_conf['source_total_daf_contributions'] == 'Confirmed') & (j_df_conf['source_total_daf_grants'] == 'Confirmed') & (j_df_conf['source_eoy_daf_assets'] == 'Confirmed')]


j_df_conf_19 = j_df_conf[(j_df_conf['fiscal_year_end'] == 2019)]
j_df_conf_20 = j_df_conf[(j_df_conf['fiscal_year_end'] == 2020)]
j_df_conf_21 = j_df_conf[(j_df_conf['fiscal_year_end'] == 2021)]
j_df_conf_22 = j_df_conf[(j_df_conf['fiscal_year_end'] == 2022)]
j_df_conf_23 = j_df_conf[(j_df_conf['fiscal_year_end'] == 2023)]
j_df_conf_24 = j_df_conf[(j_df_conf['fiscal_year_end'] == 2020)]

# %%
df = pd.read_excel('historical DAF sponsor data.xlsx')

# %%
'''Relabeling Column Data Per Year'''

columns2024 = ['EIN','Sponsoring Charity','Type','2024 Data Source', '2024 Assets', '2024 Grants', '2024 Funds', '2024 Contributions']
columns2024 = df[columns2024]
columns2024['Year'] = 2024
columns2024 = columns2024.rename(columns = { '2024 Data Source': 'Source', '2024 Assets': "Assets", "2024 Grants": "Grants", "2024 Funds": "Funds", "2024 Contributions": "Contributions" })

columns2023 = ['EIN','Sponsoring Charity','Type','2023 Data Source', '2023 Assets', '2023 Grants', '2023 Funds', '2023 Contributions']
columns2023 = df[columns2023]
columns2023['Year'] = 2023
columns2023 = columns2023.rename(columns = { '2023 Data Source': 'Source', '2023 Assets': "Assets", "2023 Grants": "Grants", "2023 Funds": "Funds", "2023 Contributions": "Contributions" })

columns2022 = ['EIN','Sponsoring Charity','Type','2022 Data Source', '2022 Assets', '2022 Grants', '2022 Funds', '2022 Contributions']
columns2022 = df[columns2022]
columns2022['Year'] = 2022
columns2022 = columns2022.rename(columns = { '2022 Data Source': 'Source', '2022 Assets': "Assets", "2022 Grants": "Grants", "2022 Funds": "Funds", "2022 Contributions": "Contributions" })

columns2021 = ['EIN','Sponsoring Charity','Type','2021 Data Source', '2021 Assets', '2021 Grants', '2021 Funds', '2021 Contributions']
columns2021 = df[columns2021]
columns2021['Year'] = 2021
columns2021 = columns2021.rename(columns = { '2021 Data Source': 'Source', '2021 Assets': "Assets", "2021 Grants": "Grants", "2021 Funds": "Funds", "2021 Contributions": "Contributions" })

columns2020 = ['EIN','Sponsoring Charity','Type', '2020 Assets', '2020 Grants', '2020 Funds', '2020 Contributions']
columns2020 = df[columns2020]
columns2020['Year'] = 2020
columns2020['Source'] = "IRS990"
columns2020 = columns2020.rename(columns = { '2020 Assets': "Assets", "2020 Grants": "Grants", "2020 Funds": "Funds", "2020 Contributions": "Contributions" })

columns2019 = ['EIN','Sponsoring Charity','Type', '2019 Assets (Updated)', '2019 Grants (Updated)', '2019_#Funds (Updated)', '19Contributions (Updated)']
columns2019 = df[columns2019]
columns2019['Year'] = 2019
columns2019['Source'] = "IRS990"
columns2019 = columns2019.rename(columns = { '2019 Assets (Updated)': "Assets", "2019 Grants (Updated)": "Grants", "2019_#Funds (Updated)": "Funds", "19Contributions (Updated)": "Contributions" })

columns2018 = ['EIN','Sponsoring Charity','Type', '2018 Assets', '2018 Grants', '2018_#Funds', '18Contributions']
columns2018 = df[columns2018]
columns2018['Year'] = 2018
columns2018['Source'] = "IRS990"
columns2018 = columns2018.rename(columns = { '2018 Assets': "Assets", "2018 Grants": "Grants", "2018_#Funds": "Funds", "18Contributions": "Contributions" })

columns2017 = ['EIN','Sponsoring Charity','Type',
               '2017Assets','2017Grants',
               '2017_#Funds','17Contributions']

columns2017 = df[columns2017]
columns2017['Year'] = 2017
columns2017['Source'] = "IRS990"
columns2017 = columns2017.rename(columns={
    '2017Assets': 'Assets',
    '2017Grants': 'Grants',
    '2017_#Funds': 'Funds',
    '17Contributions': 'Contributions'
})

columns2016 = ['EIN','Sponsoring Charity','Type',
               '2016Assets','2016Grants',
               '2016_#Funds','16Contributions']

columns2016 = df[columns2016]
columns2016['Year'] = 2016
columns2016['Source'] = "IRS990"
columns2016 = columns2016.rename(columns={
    '2016Assets': 'Assets',
    '2016Grants': 'Grants',
    '2016_#Funds': 'Funds',
    '16Contributions': 'Contributions'
})
columns2015 = ['EIN','Sponsoring Charity','Type',
               '2015Assets','2015Grants',
               '2015_#Funds','2015Contributions']

columns2015 = df[columns2015]
columns2015['Year'] = 2015
columns2015['Source'] = "IRS990"
columns2015 = columns2015.rename(columns={
    '2015Assets': 'Assets',
    '2015Grants': 'Grants',
    '2015_#Funds': 'Funds',
    '2015Contributions': 'Contributions'
})

columns2014 = ['EIN','Sponsoring Charity','Type',
               '2014Assets','2014Grants',
               '2014_Funds#','2014Contributions']

columns2014 = df[columns2014]
columns2014['Year'] = 2014
columns2014['Source'] = "IRS990"
columns2014 = columns2014.rename(columns={
    '2014Assets': 'Assets',
    '2014Grants': 'Grants',
    '2014_Funds#': 'Funds',
    '2014Contributions': 'Contributions'
})

columns2013 = ['EIN','Sponsoring Charity','Type',
               '2013Assets','2013Grants',
               '2013_#Funds','2013Contributions']

columns2013 = df[columns2013]
columns2013['Year'] = 2013
columns2013['Source'] = "IRS990"
columns2013 = columns2013.rename(columns={
    '2013Assets': 'Assets',
    '2013Grants': 'Grants',
    '2013_#Funds': 'Funds',
    '2013Contributions': 'Contributions'
})

columns2012 = ['EIN','Sponsoring Charity','Type',
               '2012Assets','2012Grants',
               '2012_#Funds','2012Contributions']

columns2012 = df[columns2012]
columns2012['Year'] = 2012
columns2012 = columns2012.rename(columns={
    '2012Assets': 'Assets',
    '2012Grants': 'Grants',
    '2012_#Funds': 'Funds',
    '2012Contributions': 'Contributions'
})

columns2012["Source"] = "IRS990"
# Out:
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2024['Year'] = 2024
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2023['Year'] = 2023
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2022['Year'] = 2022
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2021['Year'] = 2021
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2020['Year'] = 2020
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2020['Source'] = "IRS990"
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2019['Year'] = 2019
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2019['Source'] = "IRS990"
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2018['Year'] = 2018
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2018['Source'] = "IRS990"
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2017['Year'] = 2017
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2017['Source'] = "IRS990"
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2016['Year'] = 2016
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2016['Source'] = "IRS990"
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2015['Year'] = 2015
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2015['Source'] = "IRS990"
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2014['Year'] = 2014
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2014['Source'] = "IRS990"
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2013['Year'] = 2013
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2013['Source'] = "IRS990"
# C:\Users\marsh\AppData\Local\Temp\ipykernel_14092\3006459761.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns2012['Year'] = 2012

# %%
dfvertical = pd.concat([columns2024, columns2023, columns2022, columns2021, columns2020, columns2019, columns2018, columns2017, columns2016, columns2015, columns2014, columns2013, columns2012], axis=0)
print(dfvertical["Year"].describe())
dfvertical.to_excel("Vertical Dataframe.xlsx", index=False)
# Out:
# count    16848.000000
# mean      2018.000000
# std          3.741768
# min       2012.000000
# 25%       2015.000000
# 50%       2018.000000
# 75%       2021.000000
# max       2024.000000
# Name: Year, dtype: float64
