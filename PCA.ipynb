# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_excel("Filtered Table - Combined Dataset.xlsx")

# %%
accounts_as_num = pd.to_numeric(df["Accounts"], errors="coerce")

print(accounts_as_num.isna().sum())

accounts_as_num = accounts_as_num.dropna()
print(accounts_as_num.isna().sum())

df["Accounts"] = accounts_as_num

contributions_as_num = pd.to_numeric(df["Contributions"], errors="coerce")

print(contributions_as_num.isna().sum())

contributions_as_num = contributions_as_num.dropna()
print(contributions_as_num.isna().sum())

df["Contributions"] = contributions_as_num

grants_as_num = pd.to_numeric(df["Grants"], errors="coerce")

print(grants_as_num.isna().sum())

grants_as_num = grants_as_num.dropna()
print(grants_as_num.isna().sum())

df["Grants"] = grants_as_num

assets_as_num = pd.to_numeric(df["Assets"], errors="coerce")

print(assets_as_num.isna().sum())

assets_as_num = assets_as_num.dropna()
print(assets_as_num.isna().sum())

df["Assets"] = assets_as_num
# Out:
# 6363
# 0
# 6916
# 0
# 6798
# 0
# 6443
# 0

# %%
scaler = StandardScaler()
scaled_accounts = scaler.fit_transform(df["Accounts"])
scaled_contributions = scaler.fit_transform(df["Contributions"])
scaled_grants = scaler.fit_transform(df["Grants"])
scaled_assets = scaler.fit_transform(df["Assets"])

# %%
pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 pca = PCA(n_components=2)
# ----> 2 pca_data = pca.fit_transform(scaled_data)
#
# File c:\Users\marsh\Downloads\New folder\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# ...

# %%
pca_df = pd.DataFrame(
    data=pca_data,
    columns=['PC1', 'PC2']
)

print("\nPCA Result:\n", pca_df)
