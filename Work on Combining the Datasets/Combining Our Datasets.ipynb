# %%
import pandas as pd

# %%
df = pd.read_excel('Better Vertical Dataframe.xlsx')
df2 = pd.read_excel("Relabled Last 5 Years.xlsx")

# %%
df2 = df2.rename(columns={"type": "Type"})
totaldf = pd.concat([df2, df])
totaldf.head()
# Out:
#           EIN  Year Accounts Contributions      Grants       Assets  \
# 0  10391479.0  2019    395.0    20802830.0  21188325.0  218364523.0
# 1  10391479.0  2020    410.0    26448400.0  36253809.0  231757646.0
# 2  10391479.0  2021    440.0    44675962.0  21660094.0  294062119.0
# 3  10391479.0  2022    440.0    26842585.0  42632358.0  244835865.0
# 4  10391479.0  2023    456.0    33164528.0  44959811.0  257527475.0
#
#       Source                  Type    subtype
# 0  Confirmed  Community Foundation  Community
# 1  Confirmed  Community Foundation  Community
# 2  Confirmed  Community Foundation  Community
# 3  Confirmed  Community Foundation  Community
# 4  Confirmed  Community Foundation  Community

# %%
totaldf.to_excel("Combined Datasets.xlsx", index=False)
